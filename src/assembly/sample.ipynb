# %%
import gymnasium as gym

from stable_baselines3 import SAC

env = gym.make("Pendulum-v1", render_mode="human")

model = SAC("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10000, log_interval=4)
model.save("sac_pendulum")

del model # remove to demonstrate saving and loading

model = SAC.load("sac_pendulum")

obs, info = env.reset()
while True:
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    if terminated or truncated:
        obs, info = env.reset()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.34e+03 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 21        |
# |    time_elapsed    | 37        |
# |    total_timesteps | 800       |
# | train/             |           |
# |    actor_loss      | 22.2      |
# |    critic_loss     | 0.3       |
# |    ent_coef        | 0.814     |
# |    ent_coef_loss   | -0.321    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 699       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.41e+03 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 20        |
# |    time_elapsed    | 79        |
# |    total_timesteps | 1600      |
# | train/             |           |
# |    actor_loss      | 46.6      |
# |    critic_loss     | 0.171     |
# |    ent_coef        | 0.649     |
# |    ent_coef_loss   | -0.625    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1499      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.33e+03 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 19        |
# |    time_elapsed    | 125       |
# |    total_timesteps | 2400      |
# | train/             |           |
# |    actor_loss      | 68.3      |
# |    critic_loss     | 0.198     |
# |    ent_coef        | 0.529     |
# |    ent_coef_loss   | -0.64     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2299      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.15e+03 |
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 19        |
# |    time_elapsed    | 168       |
# |    total_timesteps | 3200      |
# | train/             |           |
# |    actor_loss      | 76.1      |
# |    critic_loss     | 0.397     |
# |    ent_coef        | 0.449     |
# |    ent_coef_loss   | -0.5      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3099      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.02e+03 |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 18        |
# |    time_elapsed    | 211       |
# |    total_timesteps | 4000      |
# | train/             |           |
# |    actor_loss      | 81.2      |
# |    critic_loss     | 0.851     |
# |    ent_coef        | 0.387     |
# |    ent_coef_loss   | -0.601    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3899      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -885     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 18       |
# |    time_elapsed    | 254      |
# |    total_timesteps | 4800     |
# | train/             |          |
# |    actor_loss      | 79.5     |
# |    critic_loss     | 1.17     |
# |    ent_coef        | 0.328    |
# |    ent_coef_loss   | -0.511   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -776     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 18       |
# |    time_elapsed    | 298      |
# |    total_timesteps | 5600     |
# | train/             |          |
# |    actor_loss      | 79.9     |
# |    critic_loss     | 1.8      |
# |    ent_coef        | 0.271    |
# |    ent_coef_loss   | -0.473   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -707     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 18       |
# |    time_elapsed    | 342      |
# |    total_timesteps | 6400     |
# | train/             |          |
# |    actor_loss      | 87.1     |
# |    critic_loss     | 1.56     |
# |    ent_coef        | 0.226    |
# |    ent_coef_loss   | -0.411   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -661     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 18       |
# |    time_elapsed    | 385      |
# |    total_timesteps | 7200     |
# | train/             |          |
# |    actor_loss      | 74.6     |
# |    critic_loss     | 1.24     |
# |    ent_coef        | 0.192    |
# |    ent_coef_loss   | -0.646   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -612     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 18       |
# |    time_elapsed    | 429      |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | 78.8     |
# |    critic_loss     | 3.41     |
# |    ent_coef        | 0.162    |
# |    ent_coef_loss   | -0.195   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -572     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 18       |
# |    time_elapsed    | 473      |
# |    total_timesteps | 8800     |
# | train/             |          |
# |    actor_loss      | 73.1     |
# |    critic_loss     | 1.05     |
# |    ent_coef        | 0.136    |
# |    ent_coef_loss   | -0.346   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -537     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 18       |
# |    time_elapsed    | 516      |
# |    total_timesteps | 9600     |
# | train/             |          |
# |    actor_loss      | 74.8     |
# |    critic_loss     | 1.71     |
# |    ent_coef        | 0.113    |
# |    ent_coef_loss   | -0.273   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9499     |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 18
#      16 while True:
#      17     action, _states = model.predict(obs, deterministic=True)
# ---> 18     obs, reward, terminated, truncated, info = env.step(action)
#      19     if terminated or truncated:
#      20         obs, info = env.reset()
#
# File c:\Users\teeds\Miniconda3\envs\diamond\lib\site-packages\gymnasium\wrappers\common.py:125, in TimeLimit.step(self, action)
#     112 def step(
#     113     self, action: ActType
#     114 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     115     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#     116
#     117     Args:
#    (...)
#     123
#     124     """
# --> 125     observation, reward, terminated, truncated, info = self.env.step(action)
#     126     self._elapsed_steps += 1
#     128     if self._elapsed_steps >= self._max_episode_steps:
#
# File c:\Users\teeds\Miniconda3\envs\diamond\lib\site-packages\gymnasium\wrappers\common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File c:\Users\teeds\Miniconda3\envs\diamond\lib\site-packages\gymnasium\core.py:327, in Wrapper.step(self, action)
#     323 def step(
#     324     self, action: WrapperActType
#     325 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327     return self.env.step(action)
#
# File c:\Users\teeds\Miniconda3\envs\diamond\lib\site-packages\gymnasium\wrappers\common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File c:\Users\teeds\Miniconda3\envs\diamond\lib\site-packages\gymnasium\envs\classic_control\pendulum.py:147, in PendulumEnv.step(self, u)
#     144 self.state = np.array([newth, newthdot])
#     146 if self.render_mode == "human":
# --> 147     self.render()
#     148 # truncation=False as the time limit is handled by the `TimeLimit` wrapper added during `make`
#     149 return self._get_obs(), -costs, False, False, {}
#
# File c:\Users\teeds\Miniconda3\envs\diamond\lib\site-packages\gymnasium\envs\classic_control\pendulum.py:267, in PendulumEnv.render(self)
#     265 if self.render_mode == "human":
#     266     pygame.event.pump()
# --> 267     self.clock.tick(self.metadata["render_fps"])
#     268     pygame.display.flip()
#     270 else:  # mode == "rgb_array":
#
# KeyboardInterrupt:

# %%
import pika

parameters = pika.ConnectionParameters(
    host='localhost',  # Check this!
    port=5672,          # Default RabbitMQ port
    virtual_host='/',
    credentials=pika.PlainCredentials('pacman', 'pacman_pass')
)

connection = pika.BlockingConnection(parameters)
channel = connection.channel()
# Out:
# ---------------------------------------------------------------------------
# ProbableAuthenticationError               Traceback (most recent call last)
# Cell In[2], line 10
#       1 import pika
#       3 parameters = pika.ConnectionParameters(
#       4     host='localhost',  # Check this!
#       5     port=5672,          # Default RabbitMQ port
#       6     virtual_host='/',
#       7     credentials=pika.PlainCredentials('pacman', 'pacman_pass')
#       8 )
# ---> 10 connection = pika.BlockingConnection(parameters)
#      11 channel = connection.channel()
#
# File c:\Users\teeds\Miniconda3\envs\diamond\lib\site-packages\pika\adapters\blocking_connection.py:360, in BlockingConnection.__init__(self, parameters, _impl_class)
#     358 # Perform connection workflow
#     359 self._impl = None  # so that attribute is created in case below raises
# --> 360 self._impl = self._create_connection(parameters, _impl_class)
#     361 self._impl.add_on_close_callback(self._closed_result.set_value_once)
#
# File c:\Users\teeds\Miniconda3\envs\diamond\lib\site-packages\pika\adapters\blocking_connection.py:451, in BlockingConnection._create_connection(self, configs, impl_class)
#     449     error = on_cw_done_result.value.result
#     450     LOGGER.error('Connection workflow failed: %r', error)
# --> 451     raise self._reap_last_connection_workflow_error(error)
#     452 else:
#     453     LOGGER.info('Connection workflow succeeded: %r',
#     454                 on_cw_done_result.value.result)
#
# ProbableAuthenticationError: ConnectionClosedByBroker: (403) 'ACCESS_REFUSED - Login was refused using authentication mechanism PLAIN. For details see the broker logfile.'
